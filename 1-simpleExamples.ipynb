# %%
from src.drawProcessor     import drawProcessor
from src.drawTwoProcessors import drawTwoProcessors

# %%
## Example 1: Instruction formats and default parameters.
drawProcessor(
    ## We have 4 types of instructions.
    imem=[
        {"dest": 0, "opcode": "ALU" , "src"   : 0, "port": 0, "latency": 1, "result": 0, "name": "xx"},
        {"dest": 0, "opcode": "LOAD", "src"   : 0,                                       "name": "xx"},
        {"dest": 0, "opcode": "LOAD", "srcImm": 1,                                       "name": "xx"},
        {           "opcode": "BREZ", "src"   : 0, "offset": 2,                          "name": "br"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
    ],
    r7=1,                ## Secret locates in r7
    l1ValidArray=[False, False, False, False],  ## We have 4 memory entries. This array determines which entry is pre-filled in L1
    # defense="Baseline" ## What Spectre defense is added. Options are Baseline, InvisiSpec, GhostMinion.
    # maxCycle=None,     ## Total number of cycles being simulated. Use None to finish the imem. 
    # scale=1,           ## The size of the figure
    # xyRatio=16/9,      ## The width / height ratio of the figure
    # speed=0.8,         ## Simulation speed, the larger the faster
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="300" viewBox="0 0 700.0 300" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<image x="238.70000000000002" y="247.5" width="28.0" height="14.0" xlink:href="data:application/pdf;base64,...">\n<animate attributeName="x" dur="12.5s" values="238.70000000000002;616.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M290.43,261.5 L290.43,272.0" stroke="black" stroke-width="1.4" />\n<text x="290.43" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M328.16,261.5 L328.16,272.0" stroke="black" stroke-width="1.4" />\n<text x="328.16" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">2</text>\n<path d="M365.89000000000004,261.5 L365.89000000000004,272.0" stroke="black" stroke-width="1.4" />\n<text x="365.89000000000004" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">3</text>\n<path d="M403.62,261.5 L403.62,272.0" stroke="black" stroke-width="1.4" />\n<text x="403.62" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">4</text>\n<path d="M441.35,261.5 L441.35,272.0" stroke="black" stroke-width="1.4" />\n<text x="441.35" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">5</text>\n<path d="M479.08000000000004,261.5 L479.08000000000004,272.0" stroke="black" stroke-width="1.4" />\n<text x="479.08000000000004" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">6</text>\n<path d="M516.8100000000001,261.5 L516.8100000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="516.8100000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">7</text>\n<path d="M554.5400000000001,261.5 L554.5400000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="554.5400000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">8</text>\n<path d="M592.2700000000001,261.5 L592.2700000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="592.2700000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">9</text>\n<path d="M630.0000000000001,261.5 L630.0000000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="630.0000000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">10</text>\n<path d="M644.7,262.55 L651.0,266.75 L644.7,270.95" fill="transparent" stroke="black" stroke-width="1.4" />\n<text x="672.0" y="266.75" font-size="14.0" text-anchor="middle" dominant-baseline="central">Cycle</text>\n<path d="M175.0,276.0769230769231 L175.0,286.0" stroke="black" stroke-width="1.4" />\n<path d="M226.8,276.0769230769231 L226.8,286.0" stroke="black" stroke-width="1.4" />\n<rect x="175.0" y="28.0" width="51.80000000000001" height="49.61538461538461" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="12.5s" values="transparent;transparent;#FB8C00;#FB8C00;#616161;#616161" keyTimes="0;0.02;0.08;0.22;0.28;1" repeatCount="indefinite" fill="freeze" />\n</rect>\n<rect x="175.0" y="77.61538461538461" width="51.80000000000001" height="49.61538461538461" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="12.5s" values="transparent;transparent;#FB8C00;#FB8C00;#616161;#616161" keyTimes="0;0.12;0.18;0.52;0.58;1" repeatCount="indefinite" fill="freeze" />\n</rect>\n<rect x="175.0" y="127.23076923076923" width="51.80000000000001" height="49.61538461538461" fill="transparent" stroke="black" stroke-width="1.4">\n<ani ...

# %%
## Example 2: Use ALU.
drawProcessor(
    imem=[
        {"dest": 0, "opcode": "ALU" , "src"   : 0, "latency": 1, "port": 0, "result": 0, "name": "0"},
        {"dest": 0, "opcode": "ALU" , "src"   : 0, "latency": 1, "port": 0, "result": 0, "name": "1"},
        {"dest": 0, "opcode": "ALU" , "src"   : 0, "latency": 2, "port": 0, "result": 0, "name": "2"},
        {"dest": 0, "opcode": "ALU" , "src"   : 0, "latency": 2, "port": 0, "result": 0, "name": "3"},
        {"dest": 0, "opcode": "ALU" , "src"   : 0, "latency": 4, "port": 0, "result": 0, "name": "4"},
        {"dest": 0, "opcode": "ALU" , "src"   : 0, "latency": 4, "port": 0, "result": 0, "name": "5"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
    ],
    r7=1,
    l1ValidArray=[False, False, False, False],
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="300" viewBox="0 0 700.0 300" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<image x="238.70000000000002" y="247.5" width="28.0" height="14.0" xlink:href="data:application/pdf;base64,...">\n<animate attributeName="x" dur="22.5s" values="238.70000000000002;616.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M273.66111111111115,261.5 L273.66111111111115,272.0" stroke="black" stroke-width="1.4" />\n<text x="273.66111111111115" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M294.62222222222226,261.5 L294.62222222222226,272.0" stroke="black" stroke-width="1.4" />\n<text x="294.62222222222226" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">2</text>\n<path d="M315.58333333333337,261.5 L315.58333333333337,272.0" stroke="black" stroke-width="1.4" />\n<text x="315.58333333333337" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">3</text>\n<path d="M336.5444444444445,261.5 L336.5444444444445,272.0" stroke="black" stroke-width="1.4" />\n<text x="336.5444444444445" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">4</text>\n<path d="M357.5055555555556,261.5 L357.5055555555556,272.0" stroke="black" stroke-width="1.4" />\n<text x="357.5055555555556" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">5</text>\n<path d="M378.4666666666667,261.5 L378.4666666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="378.4666666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">6</text>\n<path d="M399.4277777777778,261.5 L399.4277777777778,272.0" stroke="black" stroke-width="1.4" />\n<text x="399.4277777777778" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">7</text>\n<path d="M420.3888888888889,261.5 L420.3888888888889,272.0" stroke="black" stroke-width="1.4" />\n<text x="420.3888888888889" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">8</text>\n<path d="M441.35,261.5 L441.35,272.0" stroke="black" stroke-width="1.4" />\n<text x="441.35" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">9</text>\n<path d="M462.31111111111113,261.5 L462.31111111111113,272.0" stroke="black" stroke-width="1.4" />\n<text x="462.31111111111113" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">10</text>\n<path d="M483.27222222222224,261.5 L483.27222222222224,272.0" stroke="black" stroke-width="1.4" />\n<text x="483.27222222222224" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">11</text>\n<path d="M504.23333333333335,261.5 L504.23333333333335,272.0" stroke="black" stroke-width="1.4" />\n<text x="504.23333333333335" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">12</text>\n<path d="M525.1944444444445,261.5 L525.1944444444445,272.0" stroke="black" stroke-width="1.4" />\n<text x="525.1944444444445" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">13</text>\n<path d="M546.1555555555556,261.5 L546.1555555555556,272.0" stroke="black" stroke-width="1.4" />\n<text x="546.1555555555556" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">14</text>\n<path d="M567.1166666666667,261.5 L567.1166666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="567.1166666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">15</text>\n<path d="M588.0777777777778,26 ...

# %%
## Example 3: Use Memory.
drawProcessor(
    imem=[
        {"dest": 1, "opcode": "LOAD", "src"   : 0, "name": "0"},
        {"dest": 0, "opcode": "LOAD", "src"   : 1, "name": "1"},
        {"dest": 0, "opcode": "LOAD", "srcImm": 3, "name": "2"},
        {"dest": 1, "opcode": "LOAD", "srcImm": 3, "name": "3"},
        {"dest": 0, "opcode": "LOAD", "srcImm": 3, "name": "4"},
        {"dest": 0, "opcode": "LOAD", "srcImm": 2, "name": "5"},
        {           "opcode": "NOP" ,              "name": "6"},
    ],
    r7=1,
    l1ValidArray=[False, False, False, False],
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="300" viewBox="0 0 700.0 300" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<image x="238.70000000000002" y="247.5" width="28.0" height="14.0" xlink:href="data:application/pdf;base64,...">\n<animate attributeName="x" dur="15.0s" values="238.70000000000002;616.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M284.1416666666667,261.5 L284.1416666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="284.1416666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M315.58333333333337,261.5 L315.58333333333337,272.0" stroke="black" stroke-width="1.4" />\n<text x="315.58333333333337" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">2</text>\n<path d="M347.02500000000003,261.5 L347.02500000000003,272.0" stroke="black" stroke-width="1.4" />\n<text x="347.02500000000003" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">3</text>\n<path d="M378.4666666666667,261.5 L378.4666666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="378.4666666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">4</text>\n<path d="M409.90833333333336,261.5 L409.90833333333336,272.0" stroke="black" stroke-width="1.4" />\n<text x="409.90833333333336" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">5</text>\n<path d="M441.35,261.5 L441.35,272.0" stroke="black" stroke-width="1.4" />\n<text x="441.35" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">6</text>\n<path d="M472.7916666666667,261.5 L472.7916666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="472.7916666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">7</text>\n<path d="M504.23333333333335,261.5 L504.23333333333335,272.0" stroke="black" stroke-width="1.4" />\n<text x="504.23333333333335" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">8</text>\n<path d="M535.6750000000001,261.5 L535.6750000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="535.6750000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">9</text>\n<path d="M567.1166666666667,261.5 L567.1166666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="567.1166666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">10</text>\n<path d="M598.5583333333334,261.5 L598.5583333333334,272.0" stroke="black" stroke-width="1.4" />\n<text x="598.5583333333334" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">11</text>\n<path d="M630.0,261.5 L630.0,272.0" stroke="black" stroke-width="1.4" />\n<text x="630.0" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">12</text>\n<path d="M644.7,262.55 L651.0,266.75 L644.7,270.95" fill="transparent" stroke="black" stroke-width="1.4" />\n<text x="672.0" y="266.75" font-size="14.0" text-anchor="middle" dominant-baseline="central">Cycle</text>\n<path d="M175.0,278.83333333333337 L175.0,286.00000000000006" stroke="black" stroke-width="1.4" />\n<path d="M226.8,278.83333333333337 L226.8,286.00000000000006" stroke="black" stroke-width="1.4" />\n<rect x="175.0" y="28.0" width="51.80000000000001" height="35.833333333333336" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="15.0s" values="transparent;transparent;#FB8C00;#FB8C00;#616161;#616161" keyTimes="0;0.017;0.067;0.35;0.4;1" repeatCount="indef ...

# %%
## Example 4: Use branch.
drawProcessor(
    imem=[
        {"dest": 1, "opcode": "LOAD", "src": 0, "latency": 1, "port": 0, "name": "0"},
        {           "opcode": "BREZ", "src": 1, "offset": 5,             "name": "br"},
        {"dest": 0, "opcode": "LOAD", "src": 1,                          "name": "2"},
        {"dest": 0, "opcode": "LOAD", "src": 0,                          "name": "3"},
        {"dest": 1, "opcode": "LOAD", "src": 7,                          "name": "4"},
        {"dest": 0, "opcode": "LOAD", "src": 0,                          "name": "5"},
        {           "opcode": "NOP" ,                                    "name": "nop"},
    ],
    r7=1,
    l1ValidArray=[False, False, False, False],
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="300" viewBox="0 0 700.0 300" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<image x="238.70000000000002" y="247.5" width="28.0" height="14.0" xlink:href="data:application/pdf;base64,...">\n<animate attributeName="x" dur="10.0s" values="238.70000000000002;616.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M299.8625,261.5 L299.8625,272.0" stroke="black" stroke-width="1.4" />\n<text x="299.8625" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M347.02500000000003,261.5 L347.02500000000003,272.0" stroke="black" stroke-width="1.4" />\n<text x="347.02500000000003" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">2</text>\n<path d="M394.1875,261.5 L394.1875,272.0" stroke="black" stroke-width="1.4" />\n<text x="394.1875" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">3</text>\n<path d="M441.35,261.5 L441.35,272.0" stroke="black" stroke-width="1.4" />\n<text x="441.35" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">4</text>\n<path d="M488.51250000000005,261.5 L488.51250000000005,272.0" stroke="black" stroke-width="1.4" />\n<text x="488.51250000000005" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">5</text>\n<path d="M535.6750000000001,261.5 L535.6750000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="535.6750000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">6</text>\n<path d="M582.8375,261.5 L582.8375,272.0" stroke="black" stroke-width="1.4" />\n<text x="582.8375" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">7</text>\n<path d="M630.0,261.5 L630.0,272.0" stroke="black" stroke-width="1.4" />\n<text x="630.0" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">8</text>\n<path d="M644.7,262.55 L651.0,266.75 L644.7,270.95" fill="transparent" stroke="black" stroke-width="1.4" />\n<text x="672.0" y="266.75" font-size="14.0" text-anchor="middle" dominant-baseline="central">Cycle</text>\n<path d="M175.0,278.83333333333337 L175.0,286.00000000000006" stroke="black" stroke-width="1.4" />\n<path d="M226.8,278.83333333333337 L226.8,286.00000000000006" stroke="black" stroke-width="1.4" />\n<rect x="175.0" y="28.0" width="51.80000000000001" height="35.833333333333336" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="10.0s" values="transparent;transparent;#FB8C00;#FB8C00;#616161;#616161" keyTimes="0;0.025;0.1;0.525;0.6;1" repeatCount="indefinite" fill="freeze" />\n</rect>\n<rect x="175.0" y="63.833333333333336" width="51.80000000000001" height="35.833333333333336" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="10.0s" values="transparent;transparent;#616161;#616161" keyTimes="0;0.65;0.725;1" repeatCount="indefinite" fill="freeze" />\n</rect>\n<rect x="175.0" y="99.66666666666667" width="51.80000000000001" height="35.833333333333336" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="10.0s" values="transparent;transparent;#FB8C00;#FB8C00;#BDBDBD;#BDBDBD" keyTimes="0;0.4;0.475;0.65;0.725;1" repeatCount="indefinite" fill="freeze" />\n</rect>\n<rect x="175.0" y="135.5" width="51.80000000000001" height="35.833333333333336" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="10.0s" values="transparent;transparent;#FB8C00;#FB8C00;#BDBDBD;#BDBDBD" keyT ...

# %%
## Example 5: Show 2 simulations together with different secret values.
drawTwoProcessors(
    imem=[
        {"dest": 1, "opcode": "ALU" , "src"   : 0, "port": 0, "latency": 3, "result": 0, "name": "delay"},
        {           "opcode": "BREZ", "src"   : 1, "offset": 5,                          "name": "br"},
        {"dest": 0, "opcode": "LOAD", "src"   : 7,                                       "name": "Tx"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {"dest": 0, "opcode": "LOAD", "srcImm": 0,                                       "name": "Rx"},
    ],
    r7Pair=(0, 1),
    l1ValidArray=[False, False, False, False],
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="600" viewBox="0 0 700.0 600" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<image x="238.70000000000002" y="247.5" width="28.0" height="14.0" xlink:href="data:application/pdf;base64,...">\n<animate attributeName="x" dur="13.75s" values="238.70000000000002;616.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M287.0,261.5 L287.0,272.0" stroke="black" stroke-width="1.4" />\n<text x="287.0" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M321.3,261.5 L321.3,272.0" stroke="black" stroke-width="1.4" />\n<text x="321.3" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">2</text>\n<path d="M355.6,261.5 L355.6,272.0" stroke="black" stroke-width="1.4" />\n<text x="355.6" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">3</text>\n<path d="M389.90000000000003,261.5 L389.90000000000003,272.0" stroke="black" stroke-width="1.4" />\n<text x="389.90000000000003" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">4</text>\n<path d="M424.20000000000005,261.5 L424.20000000000005,272.0" stroke="black" stroke-width="1.4" />\n<text x="424.20000000000005" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">5</text>\n<path d="M458.5,261.5 L458.5,272.0" stroke="black" stroke-width="1.4" />\n<text x="458.5" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">6</text>\n<path d="M492.80000000000007,261.5 L492.80000000000007,272.0" stroke="black" stroke-width="1.4" />\n<text x="492.80000000000007" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">7</text>\n<path d="M527.1,261.5 L527.1,272.0" stroke="black" stroke-width="1.4" />\n<text x="527.1" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">8</text>\n<path d="M561.4000000000001,261.5 L561.4000000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="561.4000000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">9</text>\n<path d="M595.7,261.5 L595.7,272.0" stroke="black" stroke-width="1.4" />\n<text x="595.7" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">10</text>\n<path d="M630.0000000000001,261.5 L630.0000000000001,272.0" stroke="black" stroke-width="1.4" />\n<text x="630.0000000000001" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">11</text>\n<path d="M644.7,262.55 L651.0,266.75 L644.7,270.95" fill="transparent" stroke="black" stroke-width="1.4" />\n<text x="672.0" y="266.75" font-size="14.0" text-anchor="middle" dominant-baseline="central">Cycle</text>\n<path d="M175.0,278.83333333333337 L175.0,286.00000000000006" stroke="black" stroke-width="1.4" />\n<path d="M226.8,278.83333333333337 L226.8,286.00000000000006" stroke="black" stroke-width="1.4" />\n<rect x="175.0" y="28.0" width="51.80000000000001" height="35.833333333333336" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="13.75s" values="transparent;transparent;#FB8C00;#FB8C00;#616161;#616161" keyTimes="0;0.018;0.073;0.382;0.436;1" repeatCount="indefinite" fill="freeze" />\n</rect>\n<rect x="175.0" y="63.833333333333336" width="51.80000000000001" height="35.833333333333336" fill="transparent" stroke="black" stroke-width="1.4">\n<animate attributeName="fill" dur="13.75s" values="transparent;transparent;#616161;#616161" keyTimes="0;0.473;0.527;1" repeatCount="indefinite" fill="freeze" />\n</rect>\n<rect ...
