# %%
from src import Visual

# %% [markdown]
# Now you can test it

# %%
imem = [
{"dest": 0, "opcode": "ALU", "src": 0, "latency": 4, "port": 0, "name": "inst0"},
]

Visual(imem).get_draw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="500" height="500" viewBox="0 0 500 500" onload="svgOnLoad(event);">\n<defs>\n<g id="arrow">\n<path d="M0,0 L350,0" />\n<path d="M350,0 L340,-10 L340,10" />\n</g>\n</defs>\n<rect x="50" y="20" width="40" height="80" fill="none" stroke="black" stroke-width="3.0" />\n<rect x="90" y="20" width="40" height="80" fill="none" stroke="black" stroke-width="3.0" />\n<rect x="130" y="20" width="40" height="80" fill="none" stroke="black" stroke-width="3.0" />\n<rect x="170" y="20" width="40" height="80" fill="none" stroke="black" stroke-width="3.0" />\n<rect x="210" y="20" width="40" height="80" fill="none" stroke="black" stroke-width="3.0" />\n<rect x="250" y="20" width="40" height="80" fill="none" stroke="black" stroke-width="3.0" />\n<rect x="290" y="20" width="40" height="80" fill="none" stroke="black" stroke-width="3.0" />\n<rect x="330
# ...
