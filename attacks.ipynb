# %%
from src.drawProcessor     import drawProcessor
from src.drawTwoProcessors import drawTwoProcessors

# %%
## Attack 1: Spectre attack.
drawTwoProcessors(
    imem=[
        ## Instruction Template
        # {"dest": 0, "opcode": "ALU" , "src"   : 0, "port": 0, "latency": 1, "result": 0, "name": "xx"},
        # {"dest": 0, "opcode": "LOAD", "src"   : 0,                                       "name": "xx"},
        # {"dest": 0, "opcode": "LOAD", "srcImm": 0,                                       "name": "xx"},
        # {           "opcode": "BREZ", "src"   : 0, "offset": 2,                          "name": "br"},
        # {           "opcode": "NOP" ,                                                    "name": "nop"},
        
        {"dest": 1, "opcode": "ALU" , "src"   : 0, "port": 0, "latency": 3, "result": 0, "name": "delay"},
        {           "opcode": "BREZ", "src"   : 1, "offset": 5,                          "name": "br"},
        {"dest": 0, "opcode": "LOAD", "src"   : 7,                                       "name": "Tx"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {"dest": 0, "opcode": "LOAD", "srcImm": 0,                                       "name": "Rx"},
    ],
    r7Pair=(0, 1),
    l1ValidArray=[False, False, False, False],
    totalCycle=11,
    # scale=1,
    # xyRatio=7/6,
    # speed=1,
    # bufferSize=3,
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="600" viewBox="0 0 700.0 600" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<circle cx="252.70000000000002" cy="254.5" r="3.5" fill="black">\n<animate attributeName="cx" dur="11.0s" values="252.70000000000002;630.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n</circle>\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M287.0,261.5 L287.0,272.0" stroke="black" stroke-width="1.4" />\n<text x="287.0" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M321.3,261.5 L321.3,272.0" stroke="black" stroke-wid
# ...

# %%
## Attack 3-2: Break Invisible Speculation Schemes, with MSHR contention
drawTwoProcessors(
    imem=[
        {"dest": 2, "opcode": "ALU" , "src": 0, "port": 1, "latency": 5, "result": 2, "name": "dlyRx"},
        {"dest": 0, "opcode": "LOAD", "src": 2,                                       "name": "Rx"},
        {"dest": 1, "opcode": "ALU" , "src": 0, "port": 0, "latency": 2, "result": 0, "name": "dlyBr"},
        {           "opcode": "BREZ", "src": 1, "offset": 2,                          "name": "Br"},
        {"dest": 0, "opcode": "LOAD", "src": 7,                                       "name": "Tx"},
    ],
    r7Pair=(0, 1),
    l1ValidArray=[True, False, False, False],
    totalCycle=12,
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="600" viewBox="0 0 700.0 600" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<circle cx="252.70000000000002" cy="254.5" r="3.5" fill="black">\n<animate attributeName="cx" dur="12.0s" values="252.70000000000002;630.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n</circle>\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M284.1416666666667,261.5 L284.1416666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="284.1416666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M315.58333333333
# ...

# %%
## Attack 3: Break GhostMinion
drawTwoProcessors(
    imem=[
        {"dest": 1, "opcode": "ALU" , "src"   : 0, "port": 0, "latency": 1, "result": 0, "name": "dlyBr"},
        {           "opcode": "BREZ", "src"   : 1, "offset": 3,                          "name": "Br"},
        {"dest": 0, "opcode": "LOAD", "src"   : 7,                                       "name": "Tx"},
        {           "opcode": "NOP" ,                                                    "name": "nop"},
        {"dest": 0, "opcode": "LOAD", "srcImm": 2,                                       "name": "Rx"},
    ],
    r7Pair=(0, 1),
    l1ValidArray=[True, False, False, False],
    totalCycle=12
).getDraw().display_inline()
# Out:
# JupyterSvgInline(svg='<?xml version="1.0" encoding="UTF-8"?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"\n     width="700.0" height="600" viewBox="0 0 700.0 600" onload="svgOnLoad(event);">\n<defs>\n</defs>\n<circle cx="252.70000000000002" cy="254.5" r="3.5" fill="black">\n<animate attributeName="cx" dur="12.0s" values="252.70000000000002;630.0" keyTimes="0;1" repeatCount="indefinite" fill="freeze" />\n</circle>\n<path d="M252.70000000000002,266.75 L651.0,266.75" stroke="black" stroke-width="1.4" />\n<path d="M252.70000000000002,261.5 L252.70000000000002,272.0" stroke="black" stroke-width="1.4" />\n<text x="252.70000000000002" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">0</text>\n<path d="M284.1416666666667,261.5 L284.1416666666667,272.0" stroke="black" stroke-width="1.4" />\n<text x="284.1416666666667" y="279.0" font-size="14.0" text-anchor="middle" dominant-baseline="central">1</text>\n<path d="M315.58333333333
# ...
