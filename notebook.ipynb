# %%
from src import *
from IPython.display import HTML

# %% [markdown]
# Now you can test it

# %%
imem = [
{"dest": 0, "opcode": "ALU", "src": 0, "latency": 4, "port": 0, "name": "inst0"},
]

visual = Visual(imem)
HTML(visual.to_html5_video())
#HTML(visual.to_jshtml())
# Out:
# <video width="800" height="800" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
